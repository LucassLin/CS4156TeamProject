# %%
import pandas as pd
from googleapiclient.discovery import build
API_KEY = 'AIzaSyBQGzbjrOiTEfzt7xIXzHUdLy1CpVMq3Rw'
TOPIC_ID_FILE = 'topicIDs.csv'
server = build('youtube', 'v3', developerKey=API_KEY)

# %%
topics = pd.read_csv(TOPIC_ID_FILE,
                    sep=',',
                    engine='python',
                    encoding='latin-1',
                    names=['topic_id', 'subcategory', 'category'])

# %%
topics
# Out:
#       topic_id       subcategory       category
# 0      topicId       SubCategory       Category
# 1   /m/0glt670     Hip hop music          music
# 2     /m/01lyv           Country          music
# 3     /m/03_d0              Jazz          music
# 4     /m/064t9         Pop music          music
# 5     /m/06by7        Rock music          music
# 6     /m/018jz          Baseball         sports
# 7     /m/018w8        Basketball         sports
# 8     /m/02vx4          Football         sports
# 9     /m/07bs0            Tennis         sports
# 10    /m/07_53        Volleyball         sports
# 11    /m/095bb  Animated cartoon  entertainment
# 12    /m/09kqc             Humor  entertainment
# 13    /m/02vxn            Movies  entertainment
# 14    /m/05qjc   Performing arts  entertainment
# 15    /m/032tl           Fashion       lifestye
# 16   /m/027x7n           Fitness       lifestye
# 17    /m/02wbm              Food       lifestye
# 18    /m/0kt51            Health       lifestye
# 19    /m/03glg             Hobby       lifestye
# 20   /m/041xxh            Beauty       lifestye
# 21    /m/068hy              Pets       lifestye
# 22    /m/07c1v        Technology       lifestye
# 23    /m/07bxq           Tourism       lifestye
# 24    /m/07yv9          Vehicles       lifestye
# 25   /m/01k8wb         Knowledge      knowledge
# 26    /m/098wr           Society        society

# %%
channel_id = []
channel_title = []
channel_desc = []
channel_keywords = []
channel_thumbnails = []
channel_country = []
channel_language = []
channel_viewCount= []
channel_subscriberCount = []
channel_videoCount = []
channel_topicId = []
made_for_kids = []


for i in range(len(topics)):
    request = server.search().list(part='snippet',type='channel',
                                   order='viewCount',safeSearch='strict',topicId=topic_id['topic_id'][i],
                                   maxResults=5)
    response = request.execute()
    for item in response['items']:
        channelId = item['id']['channelId']
        request = server.channels().list(part='status', id=channelId)
        response = request.execute()
        if response['items'][0]['status']['isLinked'] == True and response['items'][0]['status']['privacyStatus'] == 'public':
            channel_id.append(item['id']['channelId'])
            channel_title.append(item['snippet']['title'])
            if 'description' in item['snippet']:
                channel_desc.append(item['snippet']['description'])
            else:
                channel_desc.append('NA')
            if 'thumbnails' in item['snippet'] and 'medium' in item['snippet']['thumbnails']:
                channel_thumbnails.append(item['snippet']['thumbnails']['medium'])
            else:
                 channel_thumbnails.append('NA')
        if 'madeForKids' in response['items'][0]['status']:
            made_for_kids.append(response['items'][0]['status']['madeForKids'])
        else:
            made_for_kids.append('NA')
        
for channelId in channel_id:
    request = server.channels().list(part='brandingSettings', id=channelId)
    response = request.execute()
    if 'keywords' in response['items'][0]['brandingSettings']['channel']:
        channel_keywords.append(response['items'][0]['brandingSettings']['channel']['keywords'])
    else:
        channel_keywords.append('')
    
    request = server.channels().list(part='snippet', id=channelId)
    response = request.execute()
    if 'country' in response['items'][0]['snippet']:
        channel_country.append(response['items'][0]['snippet']['country'])
    else:
        channel_country.append('NA')
        
    if 'defaultLanguage' in response['items'][0]['snippet']:
        channel_language.append(response['items'][0]['snippet']['defaultLanguage'])
    else:
        channel_language.append('NA')
        
    request = server.channels().list(part='statistics', id=channelId)
    response = request.execute()
    if 'viewCount' in response['items'][0]['statistics']:
        channel_viewCount.append(response['items'][0]['statistics']['viewCount'])
    else:
        channel_viewCount.append('0')
    if 'subscriberCount' in response['items'][0]['statistics']:
        channel_subscriberCount.append(response['items'][0]['statistics']['subscriberCount'])
    else:
        channel_subscriberCount.append('0')
    if 'videoCount' in response['items'][0]['statistics']:
        channel_videoCount.append(response['items'][0]['statistics']['videoCount'])
    else:
        channel_videoCount.append('0')

# %%
channel_id = []
channel_title = []
channel_desc = []
channel_keywords = []
channel_thumbnails = []
channel_country = []
channel_language = []
channel_viewCount= []
channel_subscriberCount = []
channel_videoCount = []
channel_topicId = []
made_for_kids = []

# %%
data = {'id':channel_id,'title':channel_title, 'thumbnails':channel_thumbnails,
        'country':channel_country, 'language':channel_language,
       'videoCount':channel_videoCount,'viewCount':channel_viewCount, 'subscriberCount': channel_subscriberCount,
       'made for kids':made_for_kids}
df = pd.DataFrame(data)
df.head(10)
# Out:
#                          id                                   title  \
# 0  UC8-Th83bH_thdKZDJCrn88g  The Tonight Show Starring Jimmy Fallon
# 1  UCWJ2lWNubArHWmf3FIHbfcQ                                     NBA
# 2  UCrXUsMBcfTVqwAS7DKg9C0Q                   YouTube Japan 公式チャンネル
# 3  UCHkj014U2CQ2Nv0UZeYpE_A                        JustinBieberVEVO
# 4  UCJ0uqCI0Vqr2Rrt1HseGirg    The Late Late Show with James Corden
# 5  UCw8ZhLPdQ0u_Y-TLKd61hGA                   1MILLION Dance Studio
# 6  UCOmHUn--16B90oW2L6FRR3A                               BLACKPINK
# 7  UCepUWUpH45hRTi-QePdq1Bg                           Mnet Official
# 8  UCczFdwWpVEpoqb-eMm4c4dQ                         Matt Steffanina
# 9  UC9avFXTdbSo5ATvzTRnAVFg                              FUNG BROS.
#
#   thumbnails country language videoCount    viewCount subscriberCount  \
# 0         NA      US       NA       6211  13149926640        26800000
# 1         NA      US       NA      33859   7544102570        15300000
# 2         NA      NA       NA        112    271414405         1350000
# 3         NA      US       en        160  21411096580        32400000
# 4         NA      NA       NA       4393   8312824656        24900000
# 5         NA      KR       ko       2259   5854035286        22500000
# 6         NA      KR       NA        322  13418276078        52900000
# 7         NA      KR       NA      15917   7518887333         7760000
# 8         NA      US       NA        376   2261986454        12000000
# 9         NA      US       NA        879    424252998         2130000
#
#   made for kids
# 0         False
# 1            NA
# 2            NA
# 3         False
# 4         False
# 5            NA
# 6         False
# 7         False
# 8         False
# 9            NA

# %%
data = {'id':channel_id,'title':channel_title, 'country':channel_country, 'language':channel_language,
       'videoCount':channel_videoCount,'viewCount':channel_viewCount, 'subscriberCount': channel_subscriberCount,
       'made for kids':made_for_kids}
df = pd.DataFrame(data)
df.head(10)
# Out:
#                          id                                   title country  \
# 0  UC8-Th83bH_thdKZDJCrn88g  The Tonight Show Starring Jimmy Fallon      US
# 1  UCWJ2lWNubArHWmf3FIHbfcQ                                     NBA      US
# 2  UCrXUsMBcfTVqwAS7DKg9C0Q                   YouTube Japan 公式チャンネル      NA
# 3  UCHkj014U2CQ2Nv0UZeYpE_A                        JustinBieberVEVO      US
# 4  UCJ0uqCI0Vqr2Rrt1HseGirg    The Late Late Show with James Corden      NA
# 5  UCw8ZhLPdQ0u_Y-TLKd61hGA                   1MILLION Dance Studio      KR
# 6  UCOmHUn--16B90oW2L6FRR3A                               BLACKPINK      KR
# 7  UCepUWUpH45hRTi-QePdq1Bg                           Mnet Official      KR
# 8  UCczFdwWpVEpoqb-eMm4c4dQ                         Matt Steffanina      US
# 9  UC9avFXTdbSo5ATvzTRnAVFg                              FUNG BROS.      US
#
#   language videoCount    viewCount subscriberCount made for kids
# 0       NA       6211  13149926640        26800000         False
# 1       NA      33859   7544102570        15300000            NA
# 2       NA        112    271414405         1350000            NA
# 3       en        160  21411096580        32400000         False
# 4       NA       4393   8312824656        24900000         False
# 5       ko       2259   5854035286        22500000            NA
# 6       NA        322  13418276078        52900000         False
# 7       NA      15917   7518887333         7760000         False
# 8       NA        376   2261986454        12000000         False
# 9       NA        879    424252998         2130000            NA

# %%
channel_title
# Out:
# ['The Tonight Show Starring Jimmy Fallon',
#  'NBA',
#  'YouTube Japan 公式チャンネル',
#  'JustinBieberVEVO',
#  'The Late Late Show with James Corden',
#  '1MILLION Dance Studio',
#  'BLACKPINK',
#  'Mnet Official',
#  'Matt Steffanina',
#  'FUNG BROS.',
#  'Home Free',
#  'CMT',
#  'Sleepy Man',
#  'Country Now',
#  'Grand Ole Opry',
#  'PostmodernJukebox',
#  'Jazz and Blues Experience',
#  'Freshly Squeezed',
#  'Lot2learn',
#  'Nat King Cole - Topic',
#  'JustinBieberVEVO',
#  'TaylorSwiftVEVO',
#  'OneDirectionVEVO',
#  'PTXofficial',
#  'The Voice',
#  'Coldplay',
#  'ImagineDragonsVEVO',
#  'Frog Leap Studios',
#  'Jonas Brothers',
#  'Red Hot Chili Peppers',
#  'MLB',
#  '中華職棒CPBL',
#  'professionalbaseballpa',
#  'vlsports',
#  'FOX Sports',
#  'Chris Smoove',
#  'NBA',
#  'SPOTV',
#  'FreeDawkins',
#  'Skip and Shannon: UNDISPUTED',
#  'Desimpedidos',
#  'AFTV',
#  'Spencer FC',
#  'Stretford Paddock',
#  'F2Freestylers - Ultimate Soccer Skills Channel',
#  'Australian Open TV',
#  'Official ITTF Channel',
#  'ATP Tour',
#  'Wimbledon',
#  'DynamicTableTennisTV',
#  'Volleyball World',
#  'NickGalis Archive',
#  'SSUtv Sports',
#  'PLUSPL',
#  'tv2ne1',
#  'The Tonight Show Starring Jimmy Fallon',
#  'NBA',
#  'YouTube Japan 公式チャンネル',
#  'JustinBieberVEVO',
#  'The Late Late Show with James Corden',
#  'The Tonight Show Starring Jimmy Fallon',
#  'TheEllenShow',
#  'The Late Late Show with James Corden',
#  'Уральские Пельмени',
#  'Mr Bean',
#  'Walt Disney Studios',
#  'Marvel Entertainment',
#  'Illumination',
#  'CGP Grey',
#  'Kurzgesagt – In a Nutshell',
#  'The X Factor UK',
#  "Britain's Got Talent",
#  "America's Got Talent",
#  'Michael Jackson',
#  'MBCkpop',
#  'Niki and Gabi',
#  'Jenn Im',
#  'Samantha Maria',
#  'Safiya Nygaard',
#  'MakeupByTiffanyD',
#  'blogilates',
#  'Yoga With Adriene',
#  'FitnessBlender',
#  'CrossFit®',
#  'Fausto Murillo',
#  'Rosanna Pansino',
#  'Food Wishes',
#  'Tasty',
#  'Jamie Oliver',
#  'Gordon Ramsay',
#  'WIRED',
#  'Theoria Apophasis',
#  'Doctor Mike',
#  'Autostopem Na Koniec Świata',
#  'Armando Hasudungan',
#  'DigitalRev TV',
#  'The Dice Tower',
#  'LEGO',
#  "Ryan's World",
#  'Tony & Chelsea Northrup',
#  'Benjamin Urbach',
#  'Physical Attraction - Topic',
#  'Caroline Andresen',
#  'Der Date Hacker',
#  'OneTime Official',
#  'Hope For Paws - Official Rescue Channel',
#  'Animal Planet',
#  'HOA BAN FOOD',
#  'JunsKitchen',
#  'HelloDenizen',
#  'Wylsacom',
#  'Google',
#  '瀬戸弘司 / Koji Seto',
#  'Adam Savage’s Tested',
#  'Samsung',
#  'The Tonight Show Starring Jimmy Fallon',
#  'NBA',
#  'YouTube Japan 公式チャンネル',
#  'JustinBieberVEVO',
#  'The Late Late Show with James Corden',
#  'MotorTrend Channel',
#  'Mighty Car Mods',
#  'Top Gear',
#  'Red Bull',
#  'THE DRIVE',
#  'CrashCourse',
#  'Kurzgesagt – In a Nutshell',
#  'Veritasium',
#  'Numberphile',
#  'TED-Ed',
#  'The Late Show with Stephen Colbert',
#  'TED',
#  'The Majority Report w/ Sam Seder',
#  'ТСН',
#  'Khan Academy']

# %%
request = server.channels().list(part='brandingSettings', id='UCHkj014U2CQ2Nv0UZeYpE_A')
response = request.execute()

# %%
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize, pos_tag
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
channel_id[0:1]
# Out:
# ['UCHkj014U2CQ2Nv0UZeYpE_A']

# %%
channel_avgViewCount = []
channel_avgRating = []
channel_replies = []

for channelId in channel_id:
    channel_comments = []
    channel_videoId = []
    n_videos = min(int(channel_videoCount[0]), 10)
    sum_viewCount = 0
    sum_rating = 0
    request = server.search().list(part='snippet',type='video',
                                   order='viewCount', safeSearch='strict',channelId=channelId,
                                   maxResults=n_videos)
    response = request.execute()
    
    for item in response['items']:
        channel_videoId.append(item['id']['videoId'])
    
    for videoId in channel_videoId:
        request = server.videos().list(part='statistics',id=videoId)
        response = request.execute()
        sum_viewCount += int(response['items'][0]['statistics']['viewCount'])
        n_likes = int(response['items'][0]['statistics']['likeCount'])
        n_dislikes = int(response['items'][0]['statistics']['dislikeCount'])
        if n_likes == 0 and n_dislikes == 0:
            sum_rating += 0
        else:
            sum_rating += n_likes/(n_likes + n_dislikes)  
        if 'commentCount' not in response['items'][0]['statistics']:
            n_comments = 0
        else:
            n_comments = min(int(response['items'][0]['statistics']['commentCount']), 10000)
        request = server.commentThreads().list(part='snippet',videoId='9shByOh8fVE',order='relevance',
                                       textFormat='plainText',maxResults=n_comments)
        response = request.execute()
        for item in response['items']:
            reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
            channel_comments.append(reply)
    channel_replies.append(channel_comments)
    channel_avgViewCount.append(sum_viewCount/n_videos)
    channel_avgRating.append(sum_rating/n_videos)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-43-0c26816d54a8> in <module>
#      19     for videoId in channel_videoId:
#      20         request = server.videos().list(part='statistics',id=videoId)
# ---> 21         response = request.execute()
#      22         sum_viewCount += int(response['items'][0]['statistics']['viewCount'])
#      23         n_likes = int(response['items'][0]['statistics']['likeCount'])
#
# /usr/local/lib/python3.7/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.7/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     913             callback(resp)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#     917
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=statistics&id=kffacxfA7G4&key=AIzaSyDcdpgWWS7btj0HkeXD02Uy_YZM2bJhAYM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.">

# %%
request = server.commentThreads().list(part='snippet',videoId='9shByOh8fVE',order='relevance',
                                       textFormat='plainText',maxResults=n_comments)
response = request.execute()
comments = []
for item in response['items']:
    reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
    comments.append(reply)

# %%
comments[2]
# Out:
# "3:10 1 - Wanna Be Startin' Somethin'\r\n8:22 2 - This Place Hotel (aka Heartbreak Hotel)\r\n13:19 3 - Another Part of Me\r\n17:27 4 - I Just Can't Stop Loving You\r\n22:25 5 - She's Out of My Life\r\n26:17 6 - The Jackson 5 Medley:\r\nI Want You Back / The Love You Save / I'll Be There\r\n33:40 7 - Rock With You\r\n37:58 8 - Human Nature\r\n43:10 9 - Smooth Criminal\r\n50:06 10 - Dirty Diana\r\n56:50 11 - Thriller\r\nBad Groove\r\n1:15:30 12 - Workin' Day and Night\r\n1:23:25 13 - Beat It\r\n1:30:11 14 - Billie Jean\r\n1:39:10 15 - Bad\r\n1:49:05 16 - Man in the Mirror\r\n1:58:20 17 - The Way You Make Me Feel\r  (15th of July 1988 Concert)\r\n2:04:40 18 - I Just Can't Stop Loving You\r (Yokohama 1987)\r\n2:10:48 19 - Bad (Yokohama 1987)"

# %%
sum_viewCount += int(response['items'][0]['statistics']['viewCount'])
        n_likes = int(response['items'][0]['statistics']['likeCount'])
        n_dislikes = int(response['items'][0]['statistics']['dislikeCount'])
        if n_likes == 0 and n_dislikes == 0:
            sum_rating += 0
        else:
            sum_rating += n_likes/(n_likes + n_dislikes)   
        n_comments = min(int(response['items'][0]['statistics']['commentCount']), 10000)
        request = server.commentThreads().list(part='snippet',videoId='9shByOh8fVE',order='relevance',
                                       textFormat='plainText',maxResults=n_comments)
        response = request.execute()
        comments = []
        for item in response['items']:
            reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
            comments.extend([pos_tag(tokenizer.tokenize(sent)) for sent in sent_tokenize(reply)])
        channel_comments.append(comments)

# %%
request = server.videos().list(part='statistics',id='9shByOh8fVE')
response = request.execute()
response['items'][0]['statistics']
# Out:
# {'kind': 'youtube#video',
#  'etag': 'CUGfpK9wSXxZOtDXGpA_CeWFVug',
#  'id': '9shByOh8fVE',
#  'statistics': {'viewCount': '8052845',
#   'likeCount': '138460',
#   'dislikeCount': '4049',
#   'favoriteCount': '0',
#   'commentCount': '20657'}}

# %%
max(int(response['items'][0]['statistics']['commentCount']),1000)
# Out:
# 20657

# %%
videoId = channel_videoId[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2d9ed2b7f584> in <module>
# ----> 1 videoId = channel_videoId[0]
#
# NameError: name 'channel_videoId' is not defined

# %%
request = server.videos().list(part='statistics',id=videoId)
response = request.execute()
response['items'][0]['statistics']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e2a6bc564d2a> in <module>
# ----> 1 request = server.videos().list(part='statistics',id=videoId)
#       2 response = request.execute()
#       3 response['items'][0]['statistics']
#
# NameError: name 'videoId' is not defined

# %%
channel_videoId
# Out:
# ['kffacxfA7G4',
#  'oyEuk8j8imI',
#  '_Z5-P9v3F8w',
#  '4GuqB1BQVr4',
#  'CHVhwcOg6y8',
#  'gdx7gN1UyX0',
#  '8EJ3zbKTWQ8',
#  'PfGaX8G0f2E',
#  'SOI4OF7iIr4',
#  'LUjn3RpkcKY']

# %%
import shlex
tags = shlex.split(channel_keywords[1], posix=True)

# %%
text = " ".join(tag for tag in tags)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 99 words in the combination of all review.

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = set(STOPWORDS), 
                min_font_size = 10).generate(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-bb02a6e43c1f> in <module>
#       4                 background_color ='white',
#       5                 stopwords = set(STOPWORDS),
# ----> 6                 min_font_size = 10).generate(text)
#
# NameError: name 'text' is not defined

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
request = server.search().list(part='snippet',type='video',
                               order='viewCount', safeSearch='strict',channelId='UC5OrDvL9DscpcAstz7JnQGA',
                               maxResults=25)
response = request.execute()
response['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'Rk9T7r1-CPYpl4PdG48xKU1WSqo',
#   'id': {'kind': 'youtube#video', 'videoId': 'Hxgo-Qu-ZZE'},
#   'snippet': {'publishedAt': '2019-03-04T00:55:20Z',
#    'channelId': 'UC5OrDvL9DscpcAstz7JnQGA',
#    'title': 'Michael Jackson - Live In Bucharest (The Dangerous Tour)',
#    'description': "Michael Jackson - Live In Bucharest (The Dangerous Tour) Listen to more Michael Jackson: https://MichaelJackson.lnk.to/Stream Watch Michael Jackson's first ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hxgo-Qu-ZZE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Hxgo-Qu-ZZE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Hxgo-Qu-ZZE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Michael Jackson',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-03-04T00:55:20Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '2JPYSfjWGVYvEeBsgyxmgAHk2ms',
#   'id': {'kind': 'youtube#video', 'videoId': '9shByOh8fVE'},
#   'snippet': {'publishedAt': '2019-03-05T00:56:03Z',
#    'channelId': 'UC5OrDvL9DscpcAstz7JnQGA',
#    'title': 'Michael Jackson - Live At Wembley (July 16, 1988)',
#    'description': 'Michael Jackson - Live At Wembley (July 16, 1988) Listen to more Michael Jackson: https://MichaelJackson.lnk.to/Stream This particular concert took place on ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9shByOh8fVE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9shByOh8fVE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9shByOh8fVE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Michael Jackson',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-03-05T00:56:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'JBi0pNPPQ8oyU3-YksXpf3gbrqg',
#   'id': {'kind': 'youtube#video', 'videoId': 'nhcG9wqn0gU'},
#   'snippet': {'publishedAt': '2020-04-03T14:03:54Z',
#    'channelId': 'UC5OrDvL9DscpcAstz7JnQGA',
#    'title': 'Michael Jackson - Heal the World (2020)',
#    'description': '"Heal the World (2020)" by Michael Jackson As music and musical performances shared online continue to unite the world during the COVID-19 pandemic, ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nhcG9wqn0gU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nhcG9wqn0gU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nhcG9wqn0gU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Michael Jackson',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-04-03T14:03:54Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'OghkRWjKYycYWprYwihJJuGE4dY',
#   'id': {'kind': 'youtube#video', 'videoId': 'WnSFDK_H470'},
#   'snippet': {'publishedAt': '2011-10-31T15:12:20Z',
#    'channelId': 'UC5OrDvL9DscpcAstz7JnQGA',
#    'title': 'Michael Jackson - Immortal Megamix (Audio)',
#    'description': '"The Immortal Megamix" by Michael Jackson Listen to Michael Jackson: https://MichaelJackson.lnk.to/_listenYD Subscribe to the official Michael Jackson ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WnSFDK_H470/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/WnSFDK_H470/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/WnSFDK_H470/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Michael Jackson',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2011-10-31T15:12:20Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'geGy2uyUHQgTL2DnpA1_uY8UWk8',
#   'id': {'kind': 'youtube#video', 'videoId': '4_gLDTUjtD0'},
#   'snippet': {'publishedAt': '2019-10-04T10:00:01Z',
#    'channelId': 'UC5OrDvL9DscpcAstz7JnQGA',
#    'title': 'Michael Jackson’s This Is It 10th Anniversary Unboxing',
#    'description': "Watch the unboxing of Michael Jackson's This Is It 10th Anniversary Box Set Pre-Order Now: http://MichaelJackson.lnk.to/OfficialShop Listen to Michael Jackson: ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4_gLDTUjtD0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4_gLDTUjtD0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4_gLDTUjtD0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Michael Jackson',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-10-04T10:00:01Z'}}]

# %%
request = server.commentThreads().list(part='snippet',videoId='9shByOh8fVE',order='relevance',
                                       textFormat='plainText',maxResults=10000)
response = request.execute()

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
comments = []
for item in response['items']:
    reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
    comments.extend([pos_tag(tokenizer.tokenize(sent)) for sent in sent_tokenize(reply)])

# %%
#tags = set(['MD', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'RP', 'RB', 'RBR', 'RBS', 'JJ', 'JJR', 'JJS'])
tags = ['JJ','JJR','JJS']
text = []
for sent in comments:
    for word, pos_tag in sent:
        if pos_tag in tags and word not in stopwords.words('english') and word.isalpha() and wordnet.synsets(word):
            text.append(word)

# %%
t = " ".join(word for word in text)
print ("There are {} words in the combination of all review.".format(len(t)))
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = set(STOPWORDS), 
                min_font_size = 10).generate(t)
# Out:
# There are 766 words in the combination of all review.

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
