# %%
import csv
import datetime
import pandas as pd

from googleapiclient.discovery import build
API_KEY = 'AIzaSyBx-NuI7FMQy53xvNclxpuqCBGS9aEZpmc'
server = build('youtube', 'v3', developerKey=API_KEY)

# %%
CHANNEL_ID_FILE = 'channelIDs.csv'

channels = pd.read_csv(CHANNEL_ID_FILE,sep=',',engine='python',encoding='latin-1',
                    names=['channel_id','subcategory','category'])
print("Loaded {0} channels of {1} topics".format(len(channels['channel_id'][1:]), 
                                                     len(set(channels['subcategory'][1:]))))
# Out:
# Loaded 520 channels of 26 topics

# %%
titles = []
descriptions = []
thumbnails = []
countries = []
defaultLanguages = []
tags = []
videoCount = []
viewCount = []
subscriberCount = []


def channelDataAnalytics(channels):
    for i in range(1, len(channels)):
        channelId = channels['channel_id'][i]
        
        request = server.channels().list(part='snippet', id=channelId)
        response = request.execute()
        # Title
        titles.append(response['items'][0]['snippet']['title'])
        # Description
        if 'description' in response['items'][0]['snippet']:
            descriptions.append(response['items'][0]['snippet']['description'])
        else:
            descriptions.append('')
        # Rhumbnails
        thumbnails.append(response['items'][0]['snippet']['thumbnails']['high']['url'])
      
        request = server.channels().list(part='brandingSettings', id=channelId)
        response = request.execute()
        # Country
        if 'country' in response['items'][0]['brandingSettings']['channel']:
            countries.append(response['items'][0]['brandingSettings']['channel']['country'])
        else:
            countries.append('NA')
        # Default Language
        if 'defaultLanguage' in response['items'][0]['brandingSettings']['channel']:
            defaultLanguages.append(response['items'][0]['brandingSettings']['channel']['defaultLanguage'])
        else:
            defaultLanguages.append('NA')
        
        request = server.channels().list(part='topicDetails', id=channelId)
        response = request.execute()
        # Tags
        channel_tags = []
        topicCategories = response['items'][0]['topicDetails']['topicCategories']
        for category in topicCategories:
            idx = category.rfind('/')
            channel_tags.append(category[idx + 1:].replace('_', ' '))
        tags.append(channel_tags)
        
        request = server.channels().list(part='statistics', id=channelId)
        response = request.execute()
        videoCount.append(response['items'][0]['statistics']['videoCount'])
        viewCount.append(response['items'][0]['statistics']['viewCount'])
        if response['items'][0]['statistics']['hiddenSubscriberCount'] == False:
            subscriberCount.append(response['items'][0]['statistics']['subscriberCount'])
        else:
            subscriberCount.append('NA')

# %%
channelDataAnalytics(channels)

# %%
titles = []
descriptions = []
thumbnails = []
countries = []
defaultLanguages = []
tags = []
videoCount = []
viewCount = []
subscriberCount = []

# %%
channels['channel_id'][i+1],channels['subcategory'][i+1],channels['category'][i+1]
# Out:
# 'channel_id'

# %%
with open('channelAnalytics.csv', mode='w') as output_file:
        writer = csv.writer(output_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer.writerow(['channel_id','title','tags','country','default_language','videoCount','viewCount','subscriberCount','thumbnail'])
        for i in range(len(titles)):
            writer.writerow([channels['channel_id'][i+1], titles[i], tags[i], countries[i],
                            defaultLanguages[i],videoCount[i],viewCount[i],subscriberCount[i],thumbnails[i]])

# %%
with open('channelDescriptions.csv', mode='w') as output_file:
        writer = csv.writer(output_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer.writerow(['channel_id','description'])
        for i in range(len(titles)):
            writer.writerow([channels['channel_id'][i+1], descriptions[i]])

# %%
data1 = pd.read_csv('channelAnalytics.csv',sep='\t',engine='python',encoding='latin-1',
                    names=['channel_id','title','tags','country','default_language','videoCount','viewCount','subscriberCount','thumbnail'])
data1.head()

# %%
data2 = pd.read_csv('channelDescriptions.csv',sep='\t',engine='python',encoding='latin-1',
                    names=['channel_id','description'])
data2.head()
# Out:
#                  channel_id                                        description
# 0                channel_id                                        description
# 1  UCw8ZhLPdQ0u_Y-TLKd61hGA        South Korea, Seoul\n\n1MILLION Dance Studio
# 2  UCOmHUn--16B90oW2L6FRR3A  BLACKPINK Official YouTube Channel\në¸ëíí...
# 3  UCepUWUpH45hRTi-QePdq1Bg  Official Channel of World's #1 Music Channel "...
# 4  UCczFdwWpVEpoqb-eMm4c4dQ  Hey guys, thanks for checking out my channel. ...

# %%
thumbnails
# Out:
# ['https://yt3.ggpht.com/a/AATXAJwrA3MvQMvzoDYrUZwjnlcn_SS7MZADC1jdjGLxEQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwgwcqoiYKn7umZJ1KFC1M2tCjqc_Di3i0d3Ooj7Q=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJzzvexucXjd_n5jIRvEghUotrFvcZ-wR80aPeIw2Q=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJy3Khj9Z6xj70ReiVV2j5ua_p-VzeXZrFTCttFr=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzPnhwAx6pJa3a_ZcGD0Asi8uW4Z7qFE4hoUvnY=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/ytc/AAUvwnhcK_0M3Etwl6z8KvLAj4EuzJXag-lokAUc-fQh8g=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxlC20vW9J5IjNCIOba7-xXna36Z_RZ6yHU7sGHIQ=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxHIxV9txCgvtFqt_fChdnvv_SYnL3m6KUiguFZfg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxQHJ7mOIpO1OYocXxUviIZ2VqUKvQGw9-y2Hz7kA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxT7sAhEf-AQmQpj4hSq294sYqj8-KbgRRH1iKaKA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzC64mfobslcpOGGYv9hOPGE7BaR3rUbS_dA2g=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzpfgv1QRhpzgU6At27JW0KrZpBtARZFJbLoZzlcQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJw8yQMqKlvLRUffKyQ2Bzo1FH_cfdNzvR9Ws0uDXw=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwTze7cU4SpDBXsMnJ3Mt50yq4uQT9QuhWzHtFaAQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJy0vUXjCj11M8SgRcNfviWp0a9gGgBiw3KJgchwCg=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJw7D4vRD5c9Dd6qhujUSpe0kcOlGCBxEOypFfsBOQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwysPX86TPUYbiZytMdgZZIZjKqDQzj2hl19ER-qA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzpEEiVqAx25BvVf0sOlb5zeoIC9S7akXS2ZZK2CQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxM07fiWBwXPoHTJGmHo9VGe5TlkprSRqu1OOdFZw=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJx0jolzZGMj_1ZHeTwK8oCxGPfAoSkl0Gd4JODghg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwWDCJrJkbxY8HPr3ahdG4R9Ndd2uB6kpbQxO6AKQ=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxlcQ3fm37GDu_Ca5gZMf3C3yrEtkwFi-1r2E0F2l0=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzVO2YfLVtyZYBscbpS3tYMCLlE1sDR8Z2PFlKgzw=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxI-UwK3ja6fIZpAzneJ1PMgFkQFFRj8iG0UPLIig=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwNr95ZS9mCOn1GeSSU0IuHzQRShsH-CX7vwpHdww=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwd9rvKXu27LjWyBSAstoLcSF4vlf6N0rKDByXE4g=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwWH0z6f-ka-SiJJ8iMPGv9P17BAc88tz3gd7piOA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxUOs98fC5TaC-BZxP4KxAakj4UySEzmqJmiRf4=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwd9rvKXu27LjWyBSAstoLcSF4vlf6N0rKDByXE4g=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxH9k6cGykZDd2MQASdE_2-zOsswoyTnfmdLROGpA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwgoI-wIETXdUDHSq1sHZHYuX4_8R_PrMYaQyfAHg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxHDGsJB8OdQhbZoUPpTUFH86oTwamz4z8XvrGnog=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJw9ufMyGU9o74wXhfeg9SMfzJL8ajoIjrRBIwY03A=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJzdkvkw4Sd_DPc06G4Dy_mfWPm6_GfllBceTeUzzg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwAUQFiwlnbZsng9E_qY0-d9INL8cWI36iFqH2Lvg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyyD5oIydJP_igJLnrFFDf3fjQuzfWLSnsiUbnj-A=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwvy2S342DRA1qCMMAQLYDqzr-RQdq5Es3L9u_MfA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJzzYOrf41XsFswlqYkw3FYcyhT7Df77PQ03YOvZrg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyzM5olZYyOsU3VMYTTgrW1TNtBP3wqFrEfNjO3lg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJzmRmF4jOP6nyVTvuwEurNQKQmkntw7mQ8bFRCjWg=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzChqIqOf_0cdyFEnRnIFAFisRrSlkyPbkU25_9MA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzDauGKemuUzYSFdkLSjl2zLk-kj4nccLaicvO9=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/ytc/AAUvwngazY2qkEZOF5nnpPe6ybo4dwphVk15cU0TNBmKOg=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzG_nEaXtgx4PirzessrxfJk3Z4UUge4HL1yKCa=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxjRVDgIQ2xIUbjQv_4xPh1wtwe14SDftyeEkNs=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJyXkvc-4oTkwyw-wXIYo2IZO_SG3rOlWXAPKvay5Q=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzqfasyoGAHLB8nctqOd5qgqk_hMBpk3jKB1HOiMA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzf8ms8NKDLTCB-zhAnOfDot4ZSWDQZt8nh5Yigxg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwSqbbrFehKSCbeFQ3Qd9xaHtoYLwBW7pR7x8yn3w=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwQaANbSR6FlTh6WCYjT8AJi9XkGYbdtaaGtZIQpw=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJw7XTf6z_rmlWCe8LPeSRo177iW9DcmaTs0NIYW=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJyQE9IgOVyUdJiNYpFaF_K4XQ09XdTh72pzISDE=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJw6ADNBodwsNdeAFixdfliulu4ZnwiKl_gjMld2ZQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwh3pZi2UvA_0kauya1UFOqkuB_EovQXMciKhBmhA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxUTNul6tTckfAtgJOv52vYQDKN8fZYArBeQI4PlA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJx6sQNGeyowyzq1E4N5T0jDZHjeG7lKlTih7ZsmPA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJyC8GRL48WAMTQOLRYyDEpVTwLs22pUrVQUuzQq=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxPiYrapLkFlyKpVDjTnEIAw6mVrvOhKKDrJVLhlA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJz99O3V7Miy7B5Tul7RNR2BrGPUKcodWhNJ0MK4gQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJy5IJQvk_IHuuLIxEWCWHPvlJd4cWjEL2FB4dSFvg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxVSLALG7Weyw8OHbTItcdoPiRuPxXjZrPFAyq-0Q=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJymPwE0-PXbFjcJDrZ9unwi5qXZq3dWLB53ha7nwZw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwssDee1fz9wsaA7iUIFahIM8vDtEe3uYsxdiP1LU4=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyBJwjT9UusyOJzcUs-bsOccuN1sK8n8R1Ebh0k=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwi145MQRcqB9NLeovr4ejM-gWrq3QqYfcKo85rnws=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJwGVDsQjb7AQv6XBcOq3q3Ta6HNe5fbFNKoSbqx=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyaMaWnuv-PL_iUAD891EVmR6XhQUmFwvjGfvZaWg=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzjvb_P4glrCLRKwPesFyG9F8pjpofFMmBgEVMR4A=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJz8zzMbNFbGZl0Ql-aj7-rjA9uxiH0hjkACKhgwZg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxVSLALG7Weyw8OHbTItcdoPiRuPxXjZrPFAyq-0Q=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxx8seq8TT5Tu50d0owy8R8hskbgY1Pmz4VgnJxjw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxBB6CQQqAbB8zodHdto8LbNJPTjOA2zgKAzjjv5xo=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJy_Oi3hDOmmF4kcUUOLlr8mVpICzCim-QEeqPEkbA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzChqIqOf_0cdyFEnRnIFAFisRrSlkyPbkU25_9MA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJynxZIi7X4KdxYFPyVLXPaCVZwIclBuLFtkqjfQ5Q=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwuEpRs3K0n_bTwl16giLmpy-Y9oF1C3zRByh_Frw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJzjvb_P4glrCLRKwPesFyG9F8pjpofFMmBgEVMR4A=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJymPwE0-PXbFjcJDrZ9unwi5qXZq3dWLB53ha7nwZw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxBB6CQQqAbB8zodHdto8LbNJPTjOA2zgKAzjjv5xo=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxcy_toqlRnq_wSsTN7LWYvbfyr7u6Q5tq2uZwBqQ=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwuEpRs3K0n_bTwl16giLmpy-Y9oF1C3zRByh_Frw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxYKvV8ivJXbjXGr-yTsZkStrHlWQ7aVmIFD0G69Q=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJy8tSPi8Kb5LYazeHn_prZaY23ejaLqynzYZP7EFQ=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJzHZyoKTR5Z81VKKy0Wo7-t7nC9DhDklwCAothR=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwp6rhWSuO0soNzi4a6-XG_vyzRFkchZoBalGYNUA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxbVFg7UYvX06_Nx85ak5sFwJmHp0-KwxfKlNSAKw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJw-4NU-SwJRG0-kaDDAyc-KVosX1d9-qRLu-xnOCA=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwI6-bDjSxf468yy20OdbFEi1bN_4Q9k9o43Yk28A=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJz1ALAdU58lGi5vP_JQf3I2xUIEZbbqG6B67w0E=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxFMd2YQm_SGPTviRLu-l1ww4GOSX75sgXx8ZFR=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJxbEUUeeGyKT5ltGIsFzvQYLyLQsvO64UV-n_wpCA=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/ytc/AAUvwng5pHQhY24G6cQgau3mGjEYGGbRPMI4Qz8YVmX1nQ=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyNXx6oFreYIIZ4JN5b07mqfFrzz8DWqVNXjFkCuw=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJyrsvNfno_2cfnxjTj05OYTKdX_53KB01ziUdD6Rg=s800-c-k-c0x00ffffff-no-rj',
#  'https://yt3.ggpht.com/a/AATXAJyzqbYdvS09_V7NgCKt4wXsLFnUuYZjlF283p-XXg=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxo6MPexo6keE7huKIll3YRFmOtCIBmF7SjaBCp-g=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxSnm1rpCpBO8AoRw6_pWca1Je2rdr1DR3axA_6=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJwKmJAK67XJQNsHxg2xB--0TE6WuQ5G6oYrjI74=s800-c-k-c0x00ffffff-no-rj-mo',
#  'https://yt3.ggpht.com/a/AATXAJxaESguTJiHCHvlPYIAJBwce9GEqoN9IbF3uSWsdw=s800-c-k-c0x00ffffff-no-rj-mo']

# %%
channels['channel_id'][101]
# Out:
# 'UCoLrcjPV5PbUrUyXq5mjc_A'

# %%
def mostKpopularVideos(channels, k):
    popularVideos = []
    for i in range(1, len(channels[:25])):
        channelId = channels['channel_id'][i]
        k = min(k, videoCount[i])
        request = server.search().list(part='snippet',type='video',order='viewCount',safeSearch='strict',
                               channelId=channelId,maxResults=k)
        response = request.execute()
        videos = []
        for item in response['items']:
            videos.append(item['id']['videoId'])
        popularVideos.append(videos)
    return popularVideos

# %%
popularVideos = mostKpopularVideos(channels, 10)

# %%
videoId = popularVideos[0][0]
request = server.videos().list(part='statistics',id=videoId)
response = request.execute()

# %%
response['items'][0]['statistics']['commentCount']
# Out:
# '29626'

# %%
def DataAnalytics(video_id):
    avg_viewCount = 0
    avg_rating = 0
    for videoId in video_id:
        request = server.videos().list(part='statistics',id=videoId)
        response = request.execute()
        # Average View Count
        avg_viewCount += int(response['items'][0]['statistics']['viewCount'])
        # Average Rating
        likesCount = int(response['items'][0]['statistics']['likeCount'])
        dislikesCount = int(response['items'][0]['statistics']['dislikeCount'])
        if likesCount == 0 and dislikesCount == 0:
            avg_rating += 0
        else:
            avg_rating += likesCount/(likesCount + dislikesCount)
        
    avg_viewCount /= len(video_id)
    avg_rating /= len(video_id) 
    return avg_viewCount, avg_rating

# %%
avg_viewCount, avg_rating = DataAnalytics(popularVideos[9])

# %%
popularVideos[9]
# Out:
# ['0K0_KtyVZ9Q',
#  '1T73xhutNXQ',
#  'IpVf5-aTgys',
#  'WqTMRvhif3Q',
#  'BZiKc_GSakA',
#  'IuEFm84s4oI',
#  '-4LpGRcpk-M',
#  'wUUnuJXsIjA',
#  'k9dUXNcWnH8',
#  'BDIw7n0LLv8']

# %%
avg_rating
# Out:
# 0.975139932924383

# %%
request = server.commentThreads().list(part='snippet',videoId='-4LpGRcpk-M',order='relevance',
                                       textFormat='plainText',maxResults=1000)
response = request.execute()

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
comments = []
for item in response['items']:
    reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
    comments += [word.lower() for word in tokenizer.tokenize(reply) if not word.lower() in stopwords.words('english')]

# %%
adjective_tags = ['JJ', 'JJS', 'NN', 'NNS']
keywords = []
for word, pos_tag in pos_tag(comments):
    if pos_tag in adjective_tags:
        keywords.append(word)

# %%
keywords
# Out:
# ['valentina',
#  'lipsync',
#  'lips',
#  'best',
#  'song',
#  'valentina',
#  'mask',
#  'friends',
#  'like',
#  'please',
#  'anyone',
#  'valentina',
#  'elimination',
#  'words',
#  'chorus',
#  'girl',
#  'ariana',
#  'grande',
#  'valentina',
#  'best',
#  'lyrics',
#  'nina',
#  'tina',
#  'race',
#  'gurls',
#  'seulgi',
#  'irene',
#  'performance',
#  'thought',
#  'top',
#  'turn',
#  'song',
#  'keep',
#  'please',
#  'next',
#  'single',
#  'side',
#  'side',
#  'gredient',
#  'ingredient',
#  'ingredient',
#  'ingredient',
#  'ingredient',
#  'ingredient',
#  'ingredient',
#  'ingredient',
#  'love',
#  'keep',
#  'please',
#  'anybody',
#  'irene',
#  'seulgi',
#  'rv',
#  'bcuz',
#  'red',
#  'velvet',
#  'anyone',
#  'valentina',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'boy',
#  'feelings',
#  'obvious',
#  'door',
#  'tonight',
#  'deny',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'night',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'phone',
#  'call',
#  'nothing',
#  'tell',
#  'games',
#  'way',
#  'baby',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'night',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'love',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'love',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'oh',
#  'greedy',
#  'greedy',
#  'love',
#  'oh',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'valentina',
#  'crash',
#  'nina',
#  'lipsync',
#  'poor',
#  'girl',
#  'irene',
#  'seulgi',
#  'sing',
#  'song',
#  'valentinas',
#  'smile',
#  'beautiful',
#  'lip',
#  'sync',
#  'couldnt',
#  'half',
#  'win',
#  'competition',
#  'valentina',
#  'video',
#  'rip',
#  'valentina',
#  'pretty',
#  'sure',
#  'valentina',
#  'video',
#  'chaeyoung',
#  'nayeon',
#  'jihyo',
#  'catchy',
#  'beautiful',
#  'comments',
#  'val',
#  'sync',
#  'comments',
#  'lyric',
#  'video',
#  'valentina',
#  'need',
#  'sass',
#  'song',
#  'epic',
#  'turn',
#  'song',
#  'bad',
#  'time',
#  'friends',
#  'ariana',
#  'visualises',
#  'sheds',
#  'ok',
#  'fine',
#  'someone',
#  'please',
#  'tf',
#  'valentina',
#  'everybody',
#  'seulrene',
#  'snatch',
#  'change',
#  'lyrics',
#  'word',
#  'greedy',
#  'horny',
#  'sense',
#  'valentina',
#  'song',
#  'greedy',
#  'state',
#  'mind',
#  'tears',
#  'cry',
#  'right',
#  'im',
#  'state',
#  'mind',
#  'luv',
#  'im',
#  'search',
#  'im',
#  'huh',
#  'home',
#  'knowing',
#  'words',
#  'idk',
#  'parts',
#  'kpoppy',
#  'valentina',
#  'bonina',
#  'valentina',
#  'lipsync',
#  'battle',
#  'flashbacks',
#  'elimination',
#  'lip',
#  'nina',
#  'valentina',
#  'lip',
#  'sync',
#  'seulgi',
#  'irene',
#  'slay',
#  'performance',
#  'velvet',
#  'valentina',
#  'redvelvet',
#  'amazing',
#  'voice',
#  'highkey',
#  'ariana',
#  'days',
#  'dangerous',
#  'women',
#  'thanks',
#  'seulrene',
#  'amazing',
#  'song',
#  'individual',
#  'pergormance',
#  'school',
#  'nina',
#  'bo',
#  'brown',
#  'valentina',
#  'sync',
#  'rupauls',
#  'race',
#  'redvelvet',
#  'seulgi',
#  'irene',
#  'saddest',
#  'lip',
#  'sync',
#  'drag',
#  'race',
#  'valentina',
#  'vs',
#  'bonina',
#  'everyone',
#  'damn',
#  'song',
#  'keep',
#  'please',
#  'irene',
#  'seulgi',
#  'stans',
#  'come',
#  'cause',
#  'hear',
#  'original',
#  'irene',
#  'seulgi',
#  'cover',
#  'song',
#  'smtown',
#  'concert',
#  'trust',
#  'cover',
#  'lit',
#  'chaeriana',
#  'twice',
#  'roses',
#  'red',
#  'violets',
#  'blue',
#  'mask',
#  'thanks',
#  'great',
#  'song',
#  'seulgi',
#  'irene',
#  'baby',
#  'lucky',
#  'cuz',
#  'rockin',
#  'best',
#  'favorite',
#  'part',
#  'anyone',
#  'nayeon',
#  'jihyo',
#  'chaeyoung',
#  'sub',
#  'unit',
#  'jihyo',
#  'cheyeon',
#  'nayeon',
#  'comments',
#  'valentina',
#  'elimination',
#  'good',
#  'song',
#  'mask',
#  'favourite',
#  'songs',
#  'champagne',
#  'ariana',
#  'glad',
#  'songs',
#  'cuz',
#  'stop',
#  'someone',
#  'u',
#  'guys',
#  'greedy',
#  'stage',
#  'gooddd',
#  'oh',
#  'everyone',
#  'valentina',
#  'tf',
#  'great',
#  'song',
#  'ariana',
#  'cute',
#  'greedy',
#  'red',
#  'ms',
#  'hearing',
#  'twices',
#  'lit',
#  'beautiful',
#  'look',
#  'model',
#  'linda',
#  'evangelista',
#  'stone',
#  'leggings',
#  'wow',
#  'throught',
#  'riooooooooooooooooooooo',
#  'greeeedyyyyyy',
#  'gonna',
#  'hate',
#  'song',
#  'valentina',
#  'bcuz',
#  'cause',
#  'najichaeng',
#  'twiceland',
#  'favourite',
#  'ari',
#  'songs',
#  'song',
#  'grande',
#  'im',
#  'song',
#  'nice',
#  'song',
#  'glad',
#  'maskgate',
#  'valentina',
#  'fundamental',
#  'anyone',
#  'valentina',
#  'vs',
#  'nina',
#  'greedy',
#  'side',
#  'side',
#  'top',
#  'dangerous',
#  'woman',
#  'seulgi',
#  'irene',
#  'chaeyoung',
#  'jihyo',
#  'nayeon',
#  'single',
#  'idea',
#  'anyone',
#  'red',
#  'velvets',
#  'good',
#  'song',
#  'greedy',
#  'ariana',
#  'grande',
#  'valentina',
#  'stop',
#  'stop',
#  'hold',
#  'greedy',
#  'greedy',
#  'love',
#  'boy',
#  'feelings',
#  'obvious',
#  'door',
#  'tonight',
#  'deny',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'oh',
#  'yeah',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'phone',
#  'call',
#  'nothing',
#  'tell',
#  'games',
#  'way',
#  'baby',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'state',
#  'mind',
#  'oh',
#  'yeah',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'love',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'greedy',
#  'love',
#  'baby',
#  'lucky',
#  'cause',
#  'best',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'money',
#  'greedy',
#  'cause',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'oh',
#  'greedy',
#  'greedy',
#  'love',
#  'oh',
#  'greedy',
#  'cause',
#  'greedy',
#  'ooh',
#  'greedy',
#  'love',
#  'greedy',
#  'love',
#  'cause']

# %%
t = " ".join(word for word in keywords)
print ("There are {} words in the combination of all review.".format(len(t)))
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

mask = np.array(Image.open("UCoLrcjPV5PbUrUyXq5mjc_A_mask.png"))
wordcloud = WordCloud(width = 800, height = 800, 
                mask=mask,contour_width=3, contour_color='steelblue',
                background_color ='white', 
                stopwords = set(STOPWORDS), 
                min_font_size = 20).generate(t) 

#plt.figure(figsize = (8, 8), facecolor = None) 
#plt.imshow(wordcloud) 
#plt.axis("off") 
#plt.tight_layout(pad = 0) 
#plt.show()
wordcloud.to_file('UCoLrcjPV5PbUrUyXq5mjc_A_wordcloud.png')

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure()
#plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
#plt.savefig('UCoLrcjPV5PbUrUyXq5mjc_A_wordcloud.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab2962912e15> in <module>
# ----> 1 t = " ".join(word for word in keywords)
#       2 print ("There are {} words in the combination of all review.".format(len(t)))
#       3 from wordcloud import WordCloud, STOPWORDS
#       4 import matplotlib.pyplot as plt
#       5 from os import path
#
# NameError: name 'keywords' is not defined

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://yt3.ggpht.com/a/AATXAJxaESguTJiHCHvlPYIAJBwce9GEqoN9IbF3uSWsdw=s800-c-k-c0x00ffffff-no-rj-mo')
img = Image.open(BytesIO(response.content))
image_name = channels['channel_id'][101] + '.png'
img.save(image_name)
img_grey = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
img_binary = cv2.threshold(img_grey, 128, 255, cv2.THRESH_BINARY)[1]
image_name = channels['channel_id'][101] + '_mask.png'
cv2.imwrite(image_name,img_binary)
# Out:
# True

# %%
def thumbnailsProcessor(channels, i):
    response = requests.get(thumbnails[i])
    img = Image.open(BytesIO(response.content))
    image_name = channels['channel_id'][i + 1] + '.png'
    img.save(image_name)
    img_grey = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
    img_binary = cv2.threshold(img_grey, 128, 255, cv2.THRESH_BINARY)[1]
    image_name = channels['channel_id'][i + 1] + '_mask.png'
    cv2.imwrite(image_name,img_binary)

# %%
channels['channel_id'][100 + 1] + '_mask.png'
# Out:
# 'UCoLrcjPV5PbUrUyXq5mjc_A_mask.png'

# %%
popularVideos = []
channelId = 'UCHkj014U2CQ2Nv0UZeYpE_A'
k = 10
request = server.search().list(part='snippet',type='video',order='viewCount',safeSearch='strict',
                        channelId=channelId,maxResults=k)
response = request.execute()
videos = []
for item in response['items']:
    videos.append(item['id']['videoId'])
popularVideos.append(videos)

# %%
popularVideos
# Out:
# [['kffacxfA7G4',
#   'oyEuk8j8imI',
#   '_Z5-P9v3F8w',
#   '4GuqB1BQVr4',
#   'CHVhwcOg6y8',
#   'gdx7gN1UyX0',
#   '8EJ3zbKTWQ8',
#   'PfGaX8G0f2E',
#   'SOI4OF7iIr4',
#   'LUjn3RpkcKY']]

# %%
request = server.commentThreads().list(part='snippet',videoId='4GuqB1BQVr4',order='relevance',
                                       textFormat='plainText',maxResults=1000)
response = request.execute()

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
comments = []
for item in response['items']:
    reply = item['snippet']['topLevelComment']['snippet']['textOriginal']
    comments += [word.lower() for word in tokenizer.tokenize(reply) if not word.lower() in stopwords.words('english')]
adjective_tags = ['JJ', 'JJS', 'NN', 'NNS']
keywords = []
for word, pos_tag in pos_tag(comments):
    if pos_tag in adjective_tags:
        keywords.append(word)

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://yt3.ggpht.com/a/AATXAJxaESguTJiHCHvlPYIAJBwce9GEqoN9IbF3uSWsdw=s800-c-k-c0x00ffffff-no-rj-mo')
img = Image.open(BytesIO(response.content))
image_name = 'UCHkj014U2CQ2Nv0UZeYpE_A' + '.png'
img.save(image_name)
img_grey = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
img_binary = cv2.threshold(img_grey, 128, 255, cv2.THRESH_BINARY)[1]
image_name = 'UCHkj014U2CQ2Nv0UZeYpE_A' + '_mask.png'
cv2.imwrite(image_name,img_binary) 
response = requests.get(thumbnails[61])
img = Image.open(BytesIO(response.content))
image_name = 'UCHkj014U2CQ2Nv0UZeYpE_A' + '.png'
img.save(image_name)
img_grey = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
img_binary = cv2.threshold(img_grey, 128, 255, cv2.THRESH_BINARY)[1]
image_name = 'UCHkj014U2CQ2Nv0UZeYpE_A' + '_mask.png'
cv2.imwrite(image_name,img_binary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-61d33836be3f> in <module>
#       5 response = requests.get('https://yt3.ggpht.com/a/AATXAJxaESguTJiHCHvlPYIAJBwce9GEqoN9IbF3uSWsdw=s800-c-k-c0x00ffffff-no-rj-mo')
#       6 img = Image.open(BytesIO(response.content))
# ----> 7 image_name = channels['channel_id'][101] + '.png'
#       8 img.save(image_name)
#       9 img_grey = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
#
# NameError: name 'channels' is not defined

# %%
t = " ".join(word for word in keywords)
print ("There are {} words in the combination of all review.".format(len(t)))
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

mask = np.array(Image.open("UCHkj014U2CQ2Nv0UZeYpE_A_mask.png"))
wordcloud = WordCloud(width = 800, height = 800, 
                mask=mask,contour_width=3, contour_color='steelblue',
                background_color ='white', 
                stopwords = set(STOPWORDS), 
                min_font_size = 20).generate(t) 

#plt.figure(figsize = (8, 8), facecolor = None) 
#plt.imshow(wordcloud) 
#plt.axis("off") 
#plt.tight_layout(pad = 0) 
#plt.show()
wordcloud.to_file('UCHkj014U2CQ2Nv0UZeYpE_A_wordcloud.png')

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure()
#plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
#plt.savefig('UCoLrcjPV5PbUrUyXq5mjc_A_wordcloud.png')
